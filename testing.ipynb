# %%
import im_proc_functions

# %%
im_proc_functions.list_images('Images')
# Out:
# ['Abidali%20Neemuchwala.jpg',
#  'Abigail%20Johnson.jpg',
#  'Ajaypal%20Singh%20Banga.jpg',
#  'Akio%20Toyoda.jpg',
#  'Alan%20D.%20Schnitzer.jpg',
#  'Alan%20Joyce.jpg',
#  'Andrew%20Mackenzie.jpg',
#  'Andrew%20S.%20Rosen.jpg',
#  'Andrew%20Wilson.jpg',
#  'Andy%20Penn.jpg',
#  'Anil%20Ambani.jpg',
#  'Ann%20Sarnoff.jpg',
#  'Arvind%20Krishna.jpg',
#  'Ben%20van%20Beurden.jpg',
#  'Bill%20Hilf.jpg',
#  'Bill%20Stromberg.jpg',
#  'Bob%20Chapek.jpg',
#  'Bob%20Dudley.jpg',
#  'Brian%20Cornell.jpg',
#  'Brian%20Humphries.jpg',
#  'Brian%20L.%20Roberts.jpg',
#  'Brian%20Moynihan.jpg',
#  'Brian%20Peddle.jpg',
#  'B̦rje%20Ekholm.jpg',
#  'C%20Vijayakumar.jpg',
#  'Carlos%20Torres%20Vila.jpg',
#  'Carmine%20Di%20Sibio.jpg',
#  'Charles%20G.%20Koch.jpg',
#  'Charles%20Woodburn.jpg',
#  'Chris%20Beard.jpg',
#  'Christian%20Klein.jpg',
#  'Christian%20Sewing.jpg',
#  'Chua%20Sock%20Koong.jpg',
#  'Chuck%20Robbins.jpg',
#  'Daniel%20Zhang.jpg',
#  'Darius%20Adamczyk.jpg',
# ...
