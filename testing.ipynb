# %%
# %matplotlib inline
import im_proc_functions
import cv2
import os
from matplotlib import pyplot as plt
import numpy as np
from im_proc_functions.SkinDetector import skin_detector

# %%
im_list = im_proc_functions.list_images('Images')
test_image_path = im_list[0]
test_image = cv2.imread(test_image_path)
image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
pixels = np.array(image)
plt.imshow(pixels)

# %%
os.getcwd()
os.listdir(os.getcwd())
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitmodules',
#  '.idea',
#  '.ipynb_checkpoints',
#  'haarcascade_frontalface_default.xml',
#  'Images',
#  'image_scraper.ipynb',
#  'image_scraper.R',
#  'im_proc_functions',
#  'README.md',
#  'testing.ipynb']

# %%
test_face_list = im_proc_functions.detect_face(test_image_path)
# face_list = [item for sublist in [im_proc_functions.detect_face(image_path) for image_path in im_list] for item in sublist]
test_face = test_face_list[0]
print(type(test_face))
image = cv2.cvtColor(test_face, cv2.COLOR_BGR2RGB)
pixels = np.array(image)
plt.imshow(pixels)
# Out:
# <class 'cv2.CascadeClassifier'>
# 1 faces detected in Abidali%20Neemuchwala.jpg
# <class 'numpy.ndarray'>

# %%
# test_skin_list = im_proc_functions.skin_or_nothing(test_image_path)
# cv2.imshow('', test_skin_list[0])
# print(type(test_face))
# plt.imshow(test_face)
# mask = skin_detector.process(test_face)
# image = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
# pixels = np.array(image)
# plt.imshow(pixels)
f, ax = plt.subplots(1,3)
image = test_face
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
pixels = np.array(image)
ax[0].imshow(pixels)
mask = skin_detector.process(test_face)
image = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
pixels = np.array(image)
ax[1].imshow(pixels)
res = cv2.bitwise_and(test_face,test_face,mask = mask)
res_mp = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
pixels = np.array(res_mp)
ax[2].imshow(pixels)
# cv2.imshow("input", image)
# cv2.imshow("mask", mask)
# cv2.waitKey(0)

# %%
test_grey_df = im_proc_functions.add_greyscale_stats(test_face_list)
test_grey_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-39976b5bc90e> in <module>
# ----> 1 test_grey_df = im_proc_functions.add_greyscale_stats(test_face_list)
#       2 test_grey_df
#
# D:\Users\wyand\OneDrive\DU_MSc\COMP_4447_ds_tools_1\Final_stuff\Colorism-Analysis\im_proc_functions\__init__.py in add_greyscale_stats(image_list, df)
#     110         greyscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     111         cur_mean = np.true_divide(greyscale.sum(1), (greyscale != 0).sum(1))
# --> 112         cur_min = np.min(greyscale, where=greyscale != 0)
#     113         cur_max = np.max(greyscale, where=greyscale != 0)
#     114         zipped = zip(column_names, [cur_mean, min, max])
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
# ...
